# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Conv2D, Flatten, MaxPooling2D,Dense,Dropout
from tensorflow.keras.models  import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from tensorflow.compat.v1 import ConfigProto

from tensorflow.compat.v1 import InteractiveSession



config = ConfigProto()

config.gpu_options.allow_growth = True

session = InteractiveSession(config=config)

# %%
import matplotlib.pyplot as plt
def plot_imgs(item_dir, top=10):
    all_item_dirs = os.listdir(item_dir)
    item_files = [os.path.join(item_dir, file) for file in all_item_dirs][:5]
  
    plt.figure(figsize=(10, 10))
  
    for idx, img_path in enumerate(item_files):
        plt.subplot(5, 5, idx+1)
    
        img = plt.imread(img_path)
        plt.tight_layout()         
        plt.imshow(img, cmap='gray')

# %%
import os
print(os.listdir('./img'))
# Out:
# ['5s', '6s', '6sPlus', '7', 'C4', 'G4', 'Gr5', 'Note3', 'S3', 'S3Duos', 's4']

# %%
data_path = './img'

# %%
plot_imgs(data_path+'/5s')

# %%
plot_imgs(data_path+'/6s')

# %%
plot_imgs(data_path+'/6sPlus')

# %%
plot_imgs(data_path+'/7')

# %%
plot_imgs(data_path+'/C4')

# %%
plot_imgs(data_path+'/G4')

# %%
plot_imgs(data_path+'/C4')

# %%
plot_imgs(data_path+'/Gr5')

# %%
plot_imgs(data_path+'/Note3')

# %%
plot_imgs(data_path+'/S3')

# %%
plot_imgs(data_path+'/S3Duos')

# %%
plot_imgs(data_path+'/s4')

# %%
train=ImageDataGenerator(
    rescale=1./255,
    validation_split=0.1,
    width_shift_range = 0.01
    )

test=ImageDataGenerator(rescale=1./255,validation_split=0.1)

# %%
from PIL import Image
 
image1 = Image.open('./img/5s/1.jpg')
#image1.show()
imag1_size = image1.size
print(imag1_size)
# Out:
# (432, 288)

# %%
batch_size = 1

# %%
train_generator=train.flow_from_directory(data_path,target_size=(432, 288),batch_size=batch_size,class_mode='categorical',subset='training')

test_generator=test.flow_from_directory(data_path,target_size=(432, 288),batch_size=batch_size,class_mode='categorical',subset='validation')
# Out:
# Found 2970 images belonging to 11 classes.
# Found 330 images belonging to 11 classes.

# %%
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
print(labels)
# Out:
# {0: '5s', 1: '6s', 2: '6sPlus', 3: '7', 4: 'C4', 5: 'G4', 6: 'Gr5', 7: 'Note3', 8: 'S3', 9: 'S3Duos', 10: 's4'}

# %%
num_classes = 11

# %%
model = Sequential()
   
model.add(Conv2D(128,(3,3), padding='same', input_shape=(432, 288, 3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2))) 

model.add(Conv2D(128,(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(num_classes,activation='softmax')) # 다중분류

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_10 (Conv2D)           (None, 432, 288, 128)     3584
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 216, 144, 128)     0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 216, 144, 128)     147584
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 108, 72, 128)      0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 995328)            0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               127402112
# _________________________________________________________________
# dense_11 (Dense)             (None, 11)                1419
# ...

# %%
num_epochs = 100
step_size_train=train_generator.n//train_generator.batch_size
step_size_test =test_generator.n//test_generator.batch_size

sgd = tf.keras.optimizers.SGD(lr=0.01, decay=1e-6, momentum = 0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
history = model.fit(train_generator, epochs=num_epochs, steps_per_epoch=step_size_train,validation_data=test_generator,
                    validation_steps=step_size_test)
# Out:
# Epoch 1/100
# 2970/2970 [==============================] - 61s 20ms/step - loss: nan - accuracy: 0.0888 - val_loss: nan - val_accuracy: 0.0909
# Epoch 2/100
# 2970/2970 [==============================] - 61s 20ms/step - loss: nan - accuracy: 0.0851 - val_loss: nan - val_accuracy: 0.0909
# Epoch 3/100
# 2970/2970 [==============================] - 61s 20ms/step - loss: nan - accuracy: 0.0980 - val_loss: nan - val_accuracy: 0.0909
# Epoch 4/100
# 2970/2970 [==============================] - 61s 20ms/step - loss: nan - accuracy: 0.0867 - val_loss: nan - val_accuracy: 0.0909
# Epoch 5/100
# 2970/2970 [==============================] - 61s 20ms/step - loss: nan - accuracy: 0.0840 - val_loss: nan - val_accuracy: 0.0909
# Epoch 6/100
# 2970/2970 [==============================] - 61s 20ms/step - loss: nan - accuracy: 0.0959 - val_loss: nan - val_accuracy: 0.0909
# Epoch 7/100
# ...
